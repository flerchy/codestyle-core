# %%
import theano
from theano import tensor as T
import lasagne
import numpy as np
import lasagne.regularization as reg
import cv2
import time

# %%
# Out:
# (0,)

# %%
# Out:
# (0,)

# %%
from sklearn.cross_validation import train_test_split
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
print(cats.shape, dogs.shape)
# Out:
# ((0,), (0,))

# %%
X_train = np.append(cats, dogs, axis=0)
y_train = np.array([1]*len(cats) + [0]* len(dogs), dtype=np.int32)
print(X_train.shape)
print(y_train.shape)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1)
for s in (X_train, X_val, y_train, y_val):
    print(s.shape)
# Out:
# (0,)
# (0,)
# (0,)
# (0,)
# (0,)
# (0,)

# %%
def build_cnn(input_var=None):
    # As a third model, we'll create a CNN of two convolution + pooling stages
    # and a fully-connected hidden layer in front of the output layer.

    # Input layer, as usual:
    network = lasagne.layers.InputLayer(shape=(None, 1, 128, 128),
                                        input_var=input_var)
    # This time we do not apply input dropout, as it tends to work less well
    # for convolutional layers.

    # Convolutional layer with 32 kernels of size 5x5. Strided and padded
    # convolutions are supported as well; see the docstring.
    network = lasagne.layers.Conv2DLayer(
            network, num_filters=5, filter_size=(12, 12),
            nonlinearity=lasagne.nonlinearities.rectify,
            W=lasagne.init.Normal(1, 0.05))
    # Expert note: Lasagne provides alternative convolutional layers that
    # override Theano's choice of which implementation to use; for details
    # please see http://lasagne.readthedocs.org/en/latest/user/tutorial.html.
    network = lasagne.layers.DenseLayer(
            network, num_units=800,
            nonlinearity=lasagne.nonlinearities.rectify,
            W=lasagne.init.GlorotUniform())

    # Max-pooling layer of factor 2 in both dimensions:
    network = lasagne.layers.DropoutLayer(network, p=0.5)

    # Another convolution with 32 5x5 kernels, and another 2x2 pooling:
    network = lasagne.layers.DenseLayer(
            network, num_units=800,
            nonlinearity=lasagne.nonlinearities.rectify)
    
    network = lasagne.layers.DropoutLayer(network, p=0.5)
    
    # A fully-connected layer of 256 units with 50% dropout on its inputs:
    network = lasagne.layers.DenseLayer(
            network, num_units=800,
            nonlinearity=lasagne.nonlinearities.rectify)

    network = lasagne.layers.DropoutLayer(network, p=0.5)

    # And, finally, the 10-unit output layer with 50% dropout on its inputs:
    network = lasagne.layers.DenseLayer(
            network, num_units=2,
            nonlinearity=lasagne.nonlinearities.softmax)

    return network, reg.regularize_layer_params(network, reg.l1)

# %%
def iterate_minibatches(inputs, targets, batchsize, shuffle=False):
    assert len(inputs) == len(targets)
    if shuffle:
        indices = np.arange(len(inputs))
        np.random.shuffle(indices)
    for start_idx in range(0, len(inputs) - batchsize + 1, batchsize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + batchsize]
        else:
            excerpt = slice(start_idx, start_idx + batchsize)
        yield inputs[excerpt], targets[excerpt]

# %%
def main(num_epochs=100):
    # Load the dataset
    print("Loading data...")
    # Prepare Theano variables for inputs and targets
    input_var = T.tensor4('inputs')
    target_var = T.ivector('targets')

    # Create neural network model (depending on first command line parameter)
    print("Building model and compiling functions...")
    network, loss = build_cnn(input_var)
    
    # Create a loss expression for training, i.e., a scalar objective we want
    # to minimize (for our multi-class problem, it is the cross-entropy loss):
    prediction = lasagne.layers.get_output(network)
    loss += lasagne.objectives.categorical_crossentropy(prediction, target_var).mean()
    # We could add some weight decay as well here, see lasagne.regularization.

    # Create update expressions for training, i.e., how to modify the
    # parameters at each training step. Here, we'll use Stochastic Gradient
    # Descent (SGD) with Nesterov momentum, but Lasagne offers plenty more.
    params = lasagne.layers.get_all_params(network, trainable=True)
    updates = lasagne.updates.nesterov_momentum(
            loss, params, learning_rate=0.01, momentum=0.9)

    # Create a loss expression for validation/testing. The crucial difference
    # here is that we do a deterministic forward pass through the network,
    # disabling dropout layers.
    test_prediction = lasagne.layers.get_output(network, deterministic=True)
    test_loss = lasagne.objectives.categorical_crossentropy(test_prediction,
                                                            target_var)
    test_loss = test_loss.mean()
    # As a bonus, also create an expression for the classification accuracy:
    test_acc = T.mean(T.eq(T.argmax(test_prediction, axis=1), target_var),
                      dtype=theano.config.floatX)

    # Compile a function performing a training step on a mini-batch (by giving
    # the updates dictionary) and returning the corresponding training loss:
    train_fn = theano.function([input_var, target_var], loss, updates=updates)

    # Compile a second function computing the validation loss and accuracy:
    val_fn = theano.function([input_var, target_var], [test_loss, test_acc])

    # Finally, launch the training loop.
    print("Starting training...")
    # We iterate over epochs:
    for epoch in range(num_epochs):
        # In each epoch, we do a full pass over the training data:
        start_time = time.time()
        loss = []
        for inp, ans in iterate_minibatches(X_train, y_train, 128, True):
            loss.append(train_fn(inp, ans))
        avg_loss = np.array(loss).mean()
        
        
        val_err, val_acc = [], []
        for inp, ans in iterate_minibatches(X_val, y_val, 128, True):
            err, acc = val_fn(inp, ans)
            val_err.append(err)
            val_acc.append(acc)
        
        val_err = np.array(val_err)
        val_acc = np.array(val_acc)
        # Then we print the results for this epoch:
        print("Epoch {} of {} took {:.3f}s".format(
            epoch + 1, num_epochs, time.time() - start_time))
        print("  training loss:\t\t{:.6f}".format(avg_loss))
        print("  validation loss:\t\t{:.6f}".format(val_err.mean()))
        print("  validation accuracy:\t\t{:.2f}".format(
            val_acc.mean()))

# %%
main()
# Out:
# Loading data...
# Building model and compiling functions...
# Starting training...
# Epoch 1 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 2 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 3 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 4 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 5 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 6 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 7 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 8 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 9 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 10 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 11 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 12 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 13 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 14 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 15 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 16 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 17 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 18 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 19 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 20 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 21 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 22 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 23 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 24 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 25 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 26 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 27 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 28 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 29 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 30 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 31 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 32 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 33 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 34 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 35 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 36 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 37 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 38 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 39 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 40 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 41 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 42 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 43 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 44 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 45 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 46 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 47 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 48 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 49 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 50 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 51 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 52 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 53 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 54 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 55 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 56 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 57 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 58 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 59 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 60 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 61 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 62 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 63 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 64 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 65 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 66 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 67 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 68 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 69 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 70 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 71 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 72 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 73 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 74 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 75 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 76 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 77 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 78 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 79 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 80 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 81 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 82 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 83 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 84 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 85 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 86 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 87 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 88 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 89 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 90 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 91 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 92 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 93 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 94 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 95 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 96 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 97 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 98 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 99 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# Epoch 100 of 100 took 0.000s
#   training loss:		nan
#   validation loss:		nan
#   validation accuracy:		nan
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:52: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:67: RuntimeWarning: Mean of empty slice.
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:69: RuntimeWarning: Mean of empty slice.
